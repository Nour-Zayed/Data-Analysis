# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('customer_shopping_data.csv')
df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
df.invoice_no.nunique()
# Out:
# 99457

# %%
df.drop("invoice_no",axis=1,inplace=True)

# %%
df
# Out:
#       customer_id  gender  age         category  quantity    price  \
# 0         C241288  Female   28         Clothing         5  1500.40
# 1         C111565    Male   21            Shoes         3  1800.51
# 2         C266599    Male   20         Clothing         1   300.08
# 3         C988172  Female   66            Shoes         5  3000.85
# 4         C189076  Female   53            Books         4    60.60
# ...           ...     ...  ...              ...       ...      ...
# 99452     C441542  Female   45         Souvenir         5    58.65
# 99453     C569580    Male   27  Food & Beverage         2    10.46
# 99454     C103292    Male   63  Food & Beverage         2    10.46
# 99455     C800631    Male   56       Technology         4  4200.00
# 99456     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 1         Debit Card   12/12/2021    Forum Istanbul
# ...

# %% [markdown]
# #### check num of Purchases per customer

# %%
df.customer_id.nunique()
# Out:
# 99457

# %% [markdown]
# #### every customer bought once only

# %%
df.drop('customer_id',axis=1,inplace=True)

# %% [markdown]
# #### Number of males and females percentage

# %%
df.gender.value_counts()
# Out:
# gender
# Female    59482
# Male      39975
# Name: count, dtype: int64

# %%
df.gender.value_counts(normalize=True)
# Out:
# gender
# Female    0.598068
# Male      0.401932
# Name: proportion, dtype: float64

# %%
df.age.min()
# Out:
# 18

# %%
df.age.max()
# Out:
# 69

# %%
df.age.describe()
# Out:
# count    99457.000000
# mean        43.427089
# std         14.990054
# min         18.000000
# 25%         30.000000
# 50%         43.000000
# 75%         56.000000
# max         69.000000
# Name: age, dtype: float64

# %%
df.age.median()
# Out:
# 43.0

# %% [markdown]
# #### If the mean and median are close to each other, the data is clean. If they are far away, the data have outlires

# %% [markdown]
# #### check outlires

# %%
df.age.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# ####TO detect outlies mathematicaly
# df.age.mean() (+-) data.age.std() * 3
# ####the correct way to deyect outliers not boxplot

# %%
df.age.mean() + df.age.std() * 3
# Out:
# 88.39725046933611

# %%
df.age.mean() - df.age.std() * 3
# Out:
# -1.5430722817776754

# %%
df.age.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.category.nunique()
# Out:
# 8

# %%
df.category.unique()
# Out:
# array(['Clothing', 'Shoes', 'Books', 'Cosmetics', 'Food & Beverage',
#        'Toys', 'Technology', 'Souvenir'], dtype=object)

# %%
df.category.value_counts()
# Out:
# category
# Clothing           34487
# Cosmetics          15097
# Food & Beverage    14776
# Toys               10087
# Shoes              10034
# Souvenir            4999
# Technology          4996
# Books               4981
# Name: count, dtype: int64

# %%
df.category.value_counts().plot.bar()
# Out:
# <Axes: xlabel='category'>

# %%
df.quantity.value_counts()
# Out:
# quantity
# 3    20149
# 5    19990
# 2    19828
# 1    19767
# 4    19723
# Name: count, dtype: int64

# %%
df.quantity.describe()
# Out:
# count    99457.000000
# mean         3.003429
# std          1.413025
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000
# Name: quantity, dtype: float64

# %%
df.quantity.median()
# Out:
# 3.0

# %%
df
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall
# 0         5/8/2022            Kanyon
# 1       12/12/2021    Forum Istanbul
# ...

# %%
df.price.describe()
# Out:
# count    99457.000000
# mean       689.256321
# std        941.184567
# min          5.230000
# 25%         45.450000
# 50%        203.300000
# 75%       1200.320000
# max       5250.000000
# Name: price, dtype: float64

# %%
df.price.median()
# Out:
# 203.3

# %%
df.price.plot.box()
# Out:
# <Axes: >

# %%
pricelimit = df.price.mean() + df.price.std() * 3
pricelimit
# Out:
# 3512.810022569837

# %%
df[df.price > pricelimit]
# Out:
#        gender  age    category  quantity   price payment_method invoice_date  \
# 23       Male   44  Technology         5  5250.0           Cash   26/10/2021
# 53     Female   43  Technology         4  4200.0           Cash   22/02/2022
# 69     Female   44  Technology         5  5250.0    Credit Card   19/11/2021
# 363    Female   67  Technology         5  5250.0           Cash     3/1/2022
# 391      Male   47  Technology         5  5250.0     Debit Card    4/10/2022
# ...       ...  ...         ...       ...     ...            ...          ...
# 99204  Female   21  Technology         4  4200.0    Credit Card    6/12/2021
# 99224  Female   27  Technology         5  5250.0    Credit Card    10/3/2022
# 99234  Female   21  Technology         4  4200.0           Cash   23/06/2021
# 99242  Female   40  Technology         4  4200.0           Cash    10/7/2022
# 99455    Male   56  Technology         4  4200.0           Cash   16/03/2021
#
#           shopping_mall
# ...

# %%
df[~(df.price > pricelimit)]
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99451    Male   50             Toys         5   179.20           Cash
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall
# 0         5/8/2022            Kanyon
# 1       12/12/2021    Forum Istanbul
# ...

# %%
df.payment_method.value_counts()
# Out:
# payment_method
# Cash           44447
# Credit Card    34931
# Debit Card     20079
# Name: count, dtype: int64

# %%
(len(df [df.payment_method == "Cash"]) + len(df [df.payment_method == "Debit card"])) / len(df)
# Out:
# 0.4468966488030003

# %%
df.shopping_mall.value_counts()
# Out:
# shopping_mall
# Mall of Istanbul     19943
# Kanyon               19823
# Metrocity            15011
# Metropol AVM         10161
# Istinye Park          9781
# Zorlu Center          5075
# Cevahir AVM           4991
# Forum Istanbul        4947
# Viaport Outlet        4914
# Emaar Square Mall     4811
# Name: count, dtype: int64

# %%
df.invoice_date.dtype
# Out:
# dtype('O')

# %%
df["invoice_date"] = pd.to_datetime(df.invoice_date, dayfirst= True)

# %%
df
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall
# 0       2022-08-05            Kanyon
# 1       2021-12-12    Forum Istanbul
# ...

# %%
df["day"] = df.invoice_date.dt.day
df["month"] = df.invoice_date.dt.month
df["month name"] = df.invoice_date.dt.month_name()

df["year"] = df.invoice_date.dt.year

# %%
df
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#       invoice_date     shopping_mall  day  month  year month name
# ...

# %%
df["month_year"] = df.invoice_date.dt.to_period("M")

# %%
df.day.value_counts()
# Out:
# day
# 3     3426
# 4     3422
# 5     3419
# 7     3401
# 6     3396
# 25    3353
# 21    3344
# 8     3333
# 24    3326
# 19    3318
# 12    3307
# 1     3307
# 14    3299
# 23    3296
# 2     3293
# 10    3281
# 28    3252
# 20    3241
# 22    3238
# 11    3234
# 9     3210
# 15    3204
# 16    3190
# 18    3183
# 26    3179
# 17    3178
# 13    3165
# 27    3137
# 30    2871
# 29    2798
# 31    1856
# Name: count, dtype: int64

# %%
df.month.value_counts()
# Out:
# month
# 1     11608
# 2     10482
# 3      8730
# 7      7877
# 10     7764
# 5      7697
# 12     7680
# 8      7635
# 6      7581
# 11     7563
# 4      7487
# 9      7353
# Name: count, dtype: int64

# %%
df.year.value_counts()
# Out:
# year
# 2022    45551
# 2021    45382
# 2023     8524
# Name: count, dtype: int64

# %%
df [df.year == 2021]
# Out:
#        gender  age         category  quantity    price payment_method  \
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# 7      Female   32         Clothing         2   600.16    Credit Card
# ...       ...  ...              ...       ...      ...            ...
# 99448  Female   65            Shoes         4  2400.68    Credit Card
# 99451    Male   50             Toys         5   179.20           Cash
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
#
#       invoice_date     shopping_mall  day  month  year month name month year  \
# ...

# %%
df [df.year == 2021].month_year.unique()
# Out:
# <PeriodArray>
# ['2021-12', '2021-11', '2021-05', '2021-10', '2021-01', '2021-08', '2021-07',
#  '2021-04', '2021-09', '2021-06', '2021-03', '2021-02']
# Length: 12, dtype: period[M]

# %%
df [df.year == 2022].month_year.unique()
# Out:
# <PeriodArray>
# ['2022-08', '2022-05', '2022-03', '2022-12', '2022-10', '2022-07', '2022-11',
#  '2022-06', '2022-01', '2022-04', '2022-02', '2022-09']
# Length: 12, dtype: period[M]

# %%
df [df.year == 2023].month_year.unique()
# Out:
# <PeriodArray>
# ['2023-03', '2023-02', '2023-01']
# Length: 3, dtype: period[M]

# %%
df["invoice_quarter"] = df.invoice_date.dt.quarter

# %%
df
# Out:
#        gender  age         category  quantity    price payment_method  \
# 0      Female   28         Clothing         5  1500.40    Credit Card
# 1        Male   21            Shoes         3  1800.51     Debit Card
# 2        Male   20         Clothing         1   300.08           Cash
# 3      Female   66            Shoes         5  3000.85    Credit Card
# 4      Female   53            Books         4    60.60           Cash
# ...       ...  ...              ...       ...      ...            ...
# 99452  Female   45         Souvenir         5    58.65    Credit Card
# 99453    Male   27  Food & Beverage         2    10.46           Cash
# 99454    Male   63  Food & Beverage         2    10.46     Debit Card
# 99455    Male   56       Technology         4  4200.00           Cash
# 99456  Female   36         Souvenir         3    35.19    Credit Card
#
#                        invoice_date     shopping_mall  day  month  year  \
# ...

# %%
df [df.year == 2023].invoice_quarter.unique()
# Out:
# array([1], dtype=int32)

# %% [markdown]
# #### numerical with numerical =====> groupby
# #### numerical with catigorical =====> groupby

# %%
df.groupby("gender")["age"].mean()
# Out:
# gender
# Female    43.453515
# Male      43.387767
# Name: age, dtype: float64

# %%
df[df.gender == "Male"].age.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df.gender == "Female"].age.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### Catigorecal with Catigorecal ====> croostab

# %%
pd.crosstab(df.gender,df.category)
# Out:
# category  Books  Clothing  Cosmetics  Food & Beverage  Shoes  Souvenir  \
# gender
# Female     2906     20652       9070             8804   5967      3017
# Male       2075     13835       6027             5972   4067      1982
#
# category  Technology  Toys
# gender
# Female          2981  6085
# Male            2015  4002

# %%
pd.crosstab(df.gender,df.category).plot.bar()
# Out:
# <Axes: xlabel='gender'>

# %%
pd.crosstab(df.gender,df.quantity)
# Out:
# quantity      1      2      3      4      5
# gender
# Female    11824  11812  12046  11927  11873
# Male       7943   8016   8103   7796   8117

# %%
df.groupby("gender")["price"].sum()
# Out:
# gender
# Female    40931801.62
# Male      27619564.29
# Name: price, dtype: float64

# %%
df.groupby("gender")["price"].describe()
# Out:
#           count        mean         std   min    25%    50%      75%     max
# gender
# Female  59482.0  688.137615  940.791874  5.23  45.45  203.3  1200.32  5250.0
# Male    39975.0  690.920933  941.777893  5.23  40.66  203.3  1200.32  5250.0

# %%
pd.crosstab(df.gender,df.payment_method)
# Out:
# payment_method   Cash  Credit Card  Debit Card
# gender
# Female          26509        21011       11962
# Male            17938        13920        8117

# %%
pd.crosstab(df.gender,df.shopping_mall)
# Out:
# shopping_mall  Cevahir AVM  Emaar Square Mall  Forum Istanbul  Istinye Park  \
# gender
# Female                2940               2842            3016          5874
# Male                  2051               1969            1931          3907
#
# shopping_mall  Kanyon  Mall of Istanbul  Metrocity  Metropol AVM  \
# gender
# Female          11906             11902       8941          6144
# Male             7917              8041       6070          4017
#
# shopping_mall  Viaport Outlet  Zorlu Center
# gender
# Female                   2949          2968
# Male                     1965          2107

# %%
pd.crosstab(df.gender,df.shopping_mall).plot.bar()
# Out:
# <Axes: xlabel='gender'>

# %%
df.groupby("age")["price"].sum()
# Out:
# age
# 18    1211463.62
# 19    1295156.47
# 20    1251603.33
# 21    1319774.11
# 22    1424246.25
# 23    1272786.87
# 24    1385679.04
# 25    1284062.74
# 26    1329746.78
# 27    1380902.40
# 28    1349206.36
# 29    1326650.56
# 30    1372875.26
# 31    1248568.74
# 32    1225841.99
# 33    1267967.60
# 34    1303762.21
# 35    1295834.50
# 36    1293657.69
# 37    1489242.75
# 38    1367625.77
# 39    1380451.45
# 40    1361964.48
# 41    1293538.55
# 42    1353487.99
# 43    1373004.24
# 44    1375697.54
# 45    1315046.43
# 46    1375062.98
# 47    1276379.05
# 48    1370826.24
# 49    1281506.85
# 50    1264478.75
# 51    1415905.64
# 52    1308900.70
# 53    1325762.95
# 54    1272199.34
# 55    1266075.46
# 56    1248207.05
# 57    1295306.04
# 58    1301409.24
# 59    1238774.85
# 60    1323943.91
# 61    1292120.27
# 62    1298547.20
# 63    1319235.70
# 64    1427031.58
# 65    1294322.43
# 66    1299235.12
# 67    1314841.19
# 68    1330573.34
# 69    1260874.31
# ...

# %%
pd.crosstab(df.gender,df.category ,values=df.price,aggfunc="sum")
# Out:
# category     Books     Clothing   Cosmetics  Food & Beverage        Shoes  \
# gender
# Female    132956.4  18616663.12  1108432.26        137873.26  10746644.02
# Male       94020.9  12459021.52   740174.64         93695.45   7388692.87
#
# category   Souvenir  Technology       Toys
# gender
# Female    105288.48   9425850.0  658094.08
# Male       69148.35   6346200.0  428610.56

# %%
pd.crosstab(df.gender,df.category ,values=df.price,aggfunc="mean")
# Out:
# category      Books    Clothing   Cosmetics  Food & Beverage        Shoes  \
# gender
# Female    45.752374  901.446016  122.208628        15.660298  1801.012908
# Male      45.311277  900.543659  122.809796        15.689124  1816.742776
#
# category   Souvenir   Technology        Toys
# gender
# Female    34.898402  3161.975847  108.150219
# Male      34.888169  3149.478908  107.099090

# %%
pd.crosstab(df.shopping_mall,[df.category,df.gender], values=df.price,aggfunc="mean")
# Out:
# category               Books               Clothing               Cosmetics  \
# gender                Female       Male      Female        Male      Female
# shopping_mall
# Cevahir AVM        45.144966  48.368807  908.469422  885.405537  120.789505
# Emaar Square Mall  49.318085  43.217368  904.657581  930.676686  121.373134
# Forum Istanbul     46.048026  44.541000  902.494122  920.124819  126.002280
# Istinye Park       45.565209  43.927387  911.832333  906.434312  121.466498
# Kanyon             43.971318  44.990909  899.086678  901.248861  122.950244
# Mall of Istanbul   45.200412  46.682297  904.098379  899.275801  122.356277
# Metrocity          45.896599  45.547428  900.527341  889.276890  119.159306
# Metropol AVM       48.184657  44.688693  893.034689  906.237316  119.784536
# Viaport Outlet     46.202128  41.842857  902.334277  887.470638  127.005393
# Zorlu Center       46.854636  47.102727  887.944039  894.939674  127.775833
#
# ...

# %%
df.groupby("month")["price"].sum()
# Out:
# month
# 1     7932626.63
# 2     7235297.32
# 3     6007346.21
# 4     5102478.76
# 5     5346926.82
# 6     5160345.74
# 7     5552023.57
# 8     5270542.03
# 9     5115214.27
# 10    5538258.09
# 11    4995141.11
# 12    5295165.36
# Name: price, dtype: float64

# %%
df.groupby(["month","shopping_mall"])["price"].sum()
# Out:
# month  shopping_mall
# 1      Cevahir AVM           375426.34
#        Emaar Square Mall     396289.98
#        Forum Istanbul        382731.27
#        Istinye Park          788682.63
#        Kanyon               1605822.96
#                                ...
# 12     Mall of Istanbul     1038730.93
#        Metrocity             778642.98
#        Metropol AVM          542912.26
#        Viaport Outlet        278820.94
#        Zorlu Center          276024.98
# Name: price, Length: 120, dtype: float64
