# %% [markdown]
# # Pokemon

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Create a data dictionary that looks like the DataFrame below

# %%
data = {
    "evolution":["Ivysaur", "Charmeleon", "Wartortle", "Metapod"],
    "hp":[40,85,22,60],
    "name":["Bulbasaur","Charmander","Squirtle","Caterpie"],
    "pokedex":["Yes","No","Yes","No"],
    "type":["grass","fire","water","bug"]

}

# %% [markdown]
# ### Step 3. Assign it to a variable called pokemon

# %%
# Out:
#     evolution  hp        name pokedex   type
# 0     Ivysaur  45   Bulbasaur     yes  grass
# 1  Charmeleon  39  Charmander      no   fire
# 2   Wartortle  44    Squirtle     yes  water
# 3     Metapod  45    Caterpie      no    bug

# %%
pokemon  = pd.DataFrame(data)
pokemon
# Out:
#     evolution  hp        name pokedex   type
# 0     Ivysaur  40   Bulbasaur     Yes  grass
# 1  Charmeleon  85  Charmander      No   fire
# 2   Wartortle  22    Squirtle     Yes  water
# 3     Metapod  60    Caterpie      No    bug

# %% [markdown]
# ### Step 4. Ops...it seems the DataFrame columns are in alphabetical order. Place  the order of the columns as name, type, hp, evolution, pokedex

# %%
pokemon = pokemon[["name","type","hp","evolution","pokedex"]]
pokemon
# Out:
#          name   type  hp   evolution pokedex
# 0   Bulbasaur  grass  40     Ivysaur     Yes
# 1  Charmander   fire  85  Charmeleon      No
# 2    Squirtle  water  22   Wartortle     Yes
# 3    Caterpie    bug  60     Metapod      No

# %% [markdown]
# ### Step 5. Add another column called place, and insert what you have in mind.

# %%
pokemon["place"] = ["forest","volcano","ocean","garden"]
pokemon
# Out:
# <ipython-input-13-451eee53fda8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pokemon["place"] = ["forest","volcano","ocean","garden"]
#          name   type  hp   evolution pokedex    place
# 0   Bulbasaur  grass  40     Ivysaur     Yes   forest
# 1  Charmander   fire  85  Charmeleon      No  volcano
# 2    Squirtle  water  22   Wartortle     Yes    ocean
# 3    Caterpie    bug  60     Metapod      No   garden

# %% [markdown]
# ### Step 6. Present the type of each column

# %%
pokemon.dtypes
# Out:
# name         object
# type         object
# hp            int64
# evolution    object
# pokedex      object
# place        object
# dtype: object

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
# ###  Pokémon with "hp" greater than 50

# %%
hp = pokemon[pokemon['hp'] > 50]
print(hp)
# Out:
#          name  type  hp   evolution pokedex    place
# 1  Charmander  fire  85  Charmeleon      No  volcano
# 3    Caterpie   bug  60     Metapod      No   garden
